# %% [markdown]
# ### Matplotlib demo

# %%
# esto es clave para que el grafico sea representado en el notebook
# %matplotlib notebook

import matplotlib.pyplot as plt
import math

x = [i * 0.1 for i in range(0, 100)]

y1 = list(map(math.sin, x))
y2 = list(map(math.cos, x))

plt.plot(x,y1,'r')
plt.plot(x,y2,'b')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
y1
# Out:
# [0.0,
#  0.09983341664682815,
#  0.19866933079506122,
#  0.2955202066613396,
#  0.3894183423086505,
#  0.479425538604203,
#  0.5646424733950355,
#  0.6442176872376911,
#  0.7173560908995228,
#  0.7833269096274833,
#  0.8414709848078965,
#  0.8912073600614354,
#  0.9320390859672264,
#  0.963558185417193,
#  0.9854497299884603,
#  0.9974949866040544,
#  0.9995736030415051,
#  0.9916648104524686,
#  0.9738476308781951,
#  0.9463000876874145,
#  0.9092974268256817,
#  0.8632093666488738,
#  0.8084964038195901,
#  0.74570521217672,
#  0.6754631805511506,
#  0.5984721441039564,
#  0.5155013718214642,
#  0.4273798802338298,
#  0.33498815015590466,
#  0.23924932921398198,
#  0.1411200080598672,
#  0.04158066243329049,
#  -0.058374143427580086,
#  -0.15774569414324865,
#  -0.25554110202683167,
#  -0.35078322768961984,
#  -0.44252044329485246,
#  -0.5298361409084934,
#  -0.6118578909427193,
#  -0.6877661591839741,
#  -0.7568024953079282,
#  -0.8182771110644108,
#  -0.8715757724135881,
# ...
